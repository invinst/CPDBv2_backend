# %%
import pandas as pd
from tqdm import tqdm, tqdm_notebook, tqdm_pandas

from data.models import Officer
from data_importer.base.storage import AzureStorage
from data_importer.base.cleaner import DataCleaner, strip, titleize
from data_importer.base.utils.import_officer_history_helpers import import_officer_history

# %%
storage = AzureStorage(account_name='cpdbv2data', 
                       account_key='<add_your_key_here>',
                       share='cleaned-data')

import_db = 'import'

# %% [markdown]
# ## Read Unit History Data

# %%
df_all_sworn_units = pd.read_csv(storage.path_for('unit-history/all-sworn-units.csv'))
df_unit_history = pd.read_csv(storage.path_for('unit-history/unit-history.csv'))

# %%
df_all_sworn_units = df_all_sworn_units.loc[:, ['UID', 'Unit', 'Start.Date', 'End.Date']]
df_unit_history = df_unit_history.loc[:, ['UID', 'Unit', 'Start.Date', 'End.Date']]

df_all_sworn_units = df_all_sworn_units.rename(columns={
    'UID': 'officer_id',
    'Unit': 'unit',
    'Start.Date': 'start_date',
    'End.Date': 'end_date'
})

df_unit_history = df_unit_history.rename(columns={
    'UID': 'officer_id',
    'Unit': 'unit',
    'Start.Date': 'start_date',
    'End.Date': 'end_date'
})

# %% [markdown]
# ## Clean Unit History data

# %% [markdown]
# #### Concat 2 data files and drop duplicated rows

# %%
df = pd.concat([df_unit_history, df_all_sworn_units])\
        .drop_duplicates(['officer_id', 'unit', 'start_date', 'end_date'])\
        .sort_values(['officer_id', 'unit'])

# %% [markdown]
# #### Do following clean steps
# - Replace NaN value to None
# - Drop all misinfomation rows which has empty unit, start_date and end_date
# - Drop invalid rows which has start_date > end_date
# - Drop duplicated rows

# %%
df = df.where((pd.notnull(df)), None)
df = df[~((df['unit']==-999) & (df['start_date'].isnull()) & (df['end_date'].isnull()))]
df = df[~(df['start_date'] > df['end_date'])]

# %% [markdown]
# ** Sort data by `officer_id`, `unit`, `end_date`, `start_date` accordingly **

# %%
df = df.sort_values(['officer_id', 'unit', 'end_date', 'start_date'])

# %% [markdown]
# ## Import and print out the output

# %%
tqdm.pandas(tqdm_notebook(), desc='Import Officer History')
df.progress_apply(
    lambda x: import_officer_history(x, import_db), 
    axis=1
)

pd.DataFrame.from_records(OfficerHistory.objects.using(import_db).all().values(
    'id', 'officer_id','officer__first_name', 'officer__last_name', 'unit__unit_name', 'effective_date', 'end_date'
))
# Out:
# A Jupyter Widget
# Import Officer History: 220769it [13:35, 270.69it/s]
#        effective_date    end_date      id officer__first_name  \
# 0          2016-06-05        None       1             Jeffery
# 1                None  2007-03-28       2             Jeffery
# 2          2007-03-29  2016-06-04       3             Jeffery
# 3                None  2007-03-28       4              Karina
# 4          2007-03-29        None       5              Karina
# 5          1976-08-19  1976-08-20       6              Daniel
# 6          1971-01-16  1976-08-18       7              Daniel
# 7          1970-06-15  1971-01-15       8              Daniel
# 8          1976-08-21        None       9              Daniel
# 9          1996-09-12  2005-05-25      10             Anthony
# 10         1995-11-09  1996-09-11      11             Anthony
# 11         2005-05-26        None      12             Anthony
# 12         1994-12-05  1995-11-08      13             Anthony
# 13         1971-07-22  1973-06-15      14              Carmel
# 14         1969-08-16  1971-07-21      15              Carmel
# 15         1969-01-06  1969-08-15      16              Carmel
# 16         1973-06-16  1973-07-24      17              Carmel
# 17         1995-04-27        None      18              Carmel
# 18         1973-07-25  1995-04-26      19              Carmel
# 19         1976-06-22  1980-01-09      20              Carmen
# 20         1971-08-08  1976-06-21      21              Carmen
# 21         1980-01-10  1980-01-11      22              Carmen
# 22         1980-01-12        None      23              Carmen
# 23         1955-04-16  1961-04-15      24              Carmen
# 24         1954-10-16  1955-04-15      25              Carmen
# 25         1961-12-16  1965-08-18      26              Carmen
# 26         1965-08-19  1971-08-07      27              Carmen
# 27         1961-04-16  1961-12-15      28              Carmen
# 28         1997-11-06  2013-10-12      29               Terry
# 29         2013-10-13        None      30               Terry
# ...               ...         ...     ...                 ...
# 115094           None        None  115095             Cynthia
# 115095           None  1993-06-23  115096           Josephine
# 115096           None        None  115097               Doris
# 115097           None  1996-12-15  115098               Doris
# 115098           None  1987-05-27  115099               Doris
# 115099           None  1999-06-19  115100               Doris
# 115100           None  1997-12-03  115101               Doris
# 115101           None  1988-03-02  115102              Cheryl
# 115102           None  1996-12-14  115103              Cheryl
# 115103           None  1991-02-27  115104              Cheryl
# 115104           None  1986-04-02  115105              Cheryl
# 115105           None        None  115106              Cheryl
# 115106           None  1982-01-06  115107               James
# 115107           None  1987-05-31  115108               James
# 115108           None        None  115109               James
# 115109           None  1986-04-02  115110               James
# 115110           None  1988-08-17  115111               James
# 115111           None        None  115112               James
# 115112           None  1986-03-02  115113               James
# 115113           None  2006-02-01  115114               James
# 115114           None  2006-01-04  115115               James
# 115115           None        None  115116               Peter
# 115116           None  1991-01-30  115117             Michael
# 115117           None        None  115118             Michael
# 115118           None  1986-06-25  115119             Michael
# 115119           None  2010-11-10  115120             Michael
# 115120           None  2007-02-28  115121             Michael
# 115121           None  2007-02-28  115122             Michael
# 115122           None  1979-10-14  115123              Robert
# 115123           None        None  115124              Robert
#
#        officer__last_name  officer_id unit__unit_name
# 0                   Aaron           1             003
# 1                   Aaron           1             014
# 2                   Aaron           1             014
# 3                   Aaron           2             015
# 4                   Aaron           2             015
# 5                   Abate           3             001
# 6                   Abate           3             004
# 7                   Abate           3             022
# 8                   Abate           3             543
# 9                  Abbate           4             011
# 10                 Abbate           4             019
# 11                 Abbate           4             020
# 12                 Abbate           4             044
# 13                 Abbate           5             016
# 14                 Abbate           5             018
# 15                 Abbate           5             022
# 16                 Abbate           5             065
# 17                 Abbate           5             640
# 18                 Abbate           5             652
# 19                 Abbate           6             013
# 20                 Abbate           6             020
# 21                 Abbate           6             024
# 22                 Abbate           6             025
# 23                 Abbate           6             032
# 24                 Abbate           6             044
# 25                 Abbate           6             065
# 26                 Abbate           6             066
# 27                 Abbate           6             167
# 28                 Abbate           7             012
# 29                 Abbate           7             016
# ...                   ...         ...             ...
# 115094              Green       32008             171
# 115095            Hampton       32009             003
# 115096             Haynes       32010             005
# 115097             Haynes       32010             018
# 115098             Haynes       32010             044
# 115099             Haynes       32010             071
# 115100             Haynes       32010             072
# 115101            Jackson       32011             002
# 115102            Jackson       32011             004
# 115103            Jackson       32011             005
# 115104            Jackson       32011             044
# 115105            Jackson       32011             610
# 115106              Joyce       32012             015
# 115107              Joyce       32012             019
# 115108              Joyce       32012             025
# 115109             Martin       32013             002
# 115110             Martin       32013             003
# 115111             Martin       32013             018
# 115112             Martin       32013             044
# 115113             Martin       32013             142
# 115114             Martin       32013             765
# 115115              Palka       32014             044
# 115116               Simi       32015             019
# 115117               Simi       32015             050
# 115118               Simi       32015             123
# 115119               Simi       32015             123
# 115120               Simi       32015             124
# 115121               Simi       32015             276
# 115122              Smith       32016             005
# 115123              Smith       32016             602
#
# [115124 rows x 7 columns]
