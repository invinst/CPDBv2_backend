# %%
import pandas as pd
from tqdm import tqdm, tqdm_notebook

from data_importer.base.storage import AzureStorage
from data_importer.base.cleaner import DataCleaner, strip, titleize

# %%
storage = AzureStorage(account_name='cpdbv2data', 
                       account_key='your-key-here',
                       share='cleaned-data')

import_db = 'import'

# %% [markdown]
# ## Read profiles data

# %%
df = pd.read_csv(
    storage.path_for('profiles/final-profiles.csv'),
    usecols=['UID', 'First.Name', 'Last.Name']
)

df = df.rename(columns={
    'UID': 'id',
    'Last.Name': 'last_name',
    'First.Name': 'first_name'
})

# %% [markdown]
# ## Clean up the data

# %%
cleaner = DataCleaner(
    schema={
        'first_name': [strip, titleize],
        'last_name': [strip, titleize],
    }
)
cleaner.perform(df)
# Out:
# 100%|██████████| 2/2 [00:03<00:00,  1.69s/it]
#           id first_name      last_name
# 0          1    Jeffery          Aaron
# 1          2     Karina          Aaron
# 2          3     Daniel          Abate
# 3          4     Carmel         Abbate
# 4          5     Carmen         Abbate
# 5          6    Anthony         Abbate
# 6          7      Terry         Abbate
# 7          8       Leon          Abbey
# 8          9    Michael          Abbey
# 9         10       Leon          Abbey
# 10        11      Laura         Abbott
# 11        12     Andrew         Abbott
# 12        13       Dale         Abbott
# 13        14  Elizabeth         Abbott
# 14        15       Zaid       Abdallah
# 15        16       Aziz    Abdelmajeid
# 16        17     Moulay       Abdullah
# 17        18      Jason        Abejero
# 18        19  Restituto        Abejero
# 19        20    Kenneth          Abels
# 20        21    Deborah        Abelson
# 21        22     Eugene       Abington
# 22        23    Patrick          Abney
# 23        24       John        Abraham
# 24        25      Nancy        Abraham
# 25        26        Jos        Abraham
# 26        27       Paul          Abram
# 27        28    Anthony          Abram
# 28        29      Henry         Abrams
# 29        30   Nicholas       Abramson
# ...      ...        ...            ...
# 32495  32496      Jason  Vonreichbauer
# 32496  32497     Thomas          Walsh
# 32497  32498    Maureen          Weber
# 32498  32499     Steven         Witnik
# 32499  32500     System          Chris
# 32500  32501   Maximina          Marte
# 32501  32502     Carlos       Aparicio
# 32502  32503     Alicia          Blake
# 32503  32504    Kathryn         Dickey
# 32504  32505   Angelica        Dobynes
# 32505  32506    Richard        Francis
# 32506  32507     Sergio       Gallegos
# 32507  32508     Robert         Garcia
# 32508  32509      Brian         Gordon
# 32509  32510      Nakia         Harvey
# 32510  32511    Randall         Hiller
# 32511  32512      Tanoa       Kittrell
# 32512  32513      Erica       Marchand
# 32513  32514    Marisol        Mendoza
# 32514  32515       Alba        Morales
# 32515  32516    Timothy        Naleway
# 32516  32517    Sanavia        Pickett
# 32517  32518  Kimmerrie       Pikowski
# 32518  32519      David          Sebok
# 32519  32520  Christian           Shiu
# 32520  32521      James        Stewart
# 32521  32522      Kevin         Taylor
# 32522  32523   Mercedes         Watson
# 32523  32524     Dwight          White
# 32524  32525  Quinretta          White
#
# [32525 rows x 3 columns]

# %%
df = df[0:32140]

# %% [markdown]
# ## Update officer name

# %%
def update_officer_name(data):
    officer = Officer.objects.using(import_db).get(pk=data['id'])
    officer.first_name = data['first_name']
    officer.last_name = data['last_name']
    officer.save()

# 32127       No     1997-09-02      1957.0      Erwin      F  31329
# 32128       No     2013-04-01      1988.0     Dennis      M  31335
# 32129       No     1964-06-15      1940.0      April      M  31382
# 32130       No     2002-12-02      1980.0      Brent      M  31410
# 32131      Yes     2016-04-25      1981.0      James      M  31420
# 32132       No     1993-12-13      1969.0    Wallace      M  31455
# 32133  Unknown     2012-11-30      1983.0      James      M  31976
# 32134  Unknown     1985-04-08         NaN     Victor      F  32011
# 32135  Unknown     1981-03-02         NaN  Christian      F  32031
# 32136  Unknown     2006-07-16      1986.0   Maurizio      M  32063
# 32137  Unknown     2003-02-24      1972.0     George      F  32090
# 32138  Unknown     1959-03-16      1934.0      David      M  32105
# 32139  Unknown     2016-08-29      1988.0   Terrance      F  32140
#
#           last_name middle_initial      race rank suffix_name tags
# 0            Abbate           None     White             None   []
# 1            Abbate           None     White             None   []
# 2            Abbate           None     White             None   []
# 3             Abbey           None     Black             None   []
# 4             Abbey           None     Black             None   []
# 5            Abbott           None     White             None   []
# 6            Abbott           None     White             None   []
# 7            Abbott           None     White             None   []
# 8            Abbott           None     White             None   []
# 9          Abdallah           None     White             None   []
# 10      Abdelmajeid           None     White             None   []
# 11         Abdullah           None       API             None   []
# 12          Abejero           None     Black             None   []
# 13          Abejero           None       API             None   []
# 14            Abels           None       API             None   []
# 15          Abelson           None     White             None   []
# 16         Abington           None     White             None   []
# 17            Abney           None     Black             None   []
# 18          Abraham           None     White             None   []
# 19          Abraham           None     White             None   []
# 20          Abraham           None     White             None   []
# 21            Abram           None       API             None   []
# 22            Abram           None     Black             None   []
# 23           Abrams           None     Black             None   []
# 24         Abramson           None     Black             None   []
# 25            Abran           None     White             None   []
# 26        Abrasevic           None     White             None   []
# 27            Abreu           None  Hispanic             None   []
# 28            Abron           None     Black             None   []
# 29           Abston           None     Black             None   []
# ...             ...            ...       ...  ...         ...  ...
# 32110    Ziemblicki           None  Hispanic             None   []
# 32111        Zroski           None     White             None   []
# 32112     Alexander           None     White             None   []
# 32113          Bady           None     White             None   []
# 32114        Briggs           None     White             None   []
# 32115      Chapleau           None  Hispanic             None   []
# 32116         Costa           None     White             None   []
# 32117       Daniels           None     White             None   []
# 32118          Dyra           None     White             None   []
# 32119       Fuentes           None  Hispanic             None   []
# 32120          Wood           None     Black             None   []
# 32121      Woodruff           None     Black             None   []
# 32122         Woods           None     White             None   []
# 32123       Worsham           None     White             None   []
# 32124       Wortham           None     White             None   []
# 32125        Wright           None     White             None   []
# 32126        Wrobel           None     White             None   []
# 32127      Wykowski           None     White             None   []
# 32128          Wynn           None     White             None   []
# 32129         Yates           None     White             None   []
# 32130     Yoshikawa           None     Black             None   []
# 32131         Young           None     Black             None   []
# 32132         Young           None     Black             None   []
# 32133     Gallagher           None  Hispanic             None   []
# 32134       Gurrola           None     Black             None   []
# 32135  Hattenberger           None     White             None   []
# 32136       Inzerra           None                       None   []
# 32137     Karuntzos           None                       None   []
# 32138   Kleinfelder           None                       None   []
# 32139        Looney           None                       None   []
#
# [32140 rows x 12 columns]
