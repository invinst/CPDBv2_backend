# %%
import pandas as pd
import numpy as np
from tqdm import tqdm, tqdm_notebook, tqdm_pandas

from data.models import Victim, Allegation
from data_importer.base.cleaner import DataCleaner, strip, titleize
from data_importer.base.storage import AzureStorage

# %%
storage = AzureStorage(account_name='cpdbv2data', 
                       account_key='your-key-here',
                       share='cleaned-data')
import_db = 'import'

# %%
gender_dict = {
    'MALE': 'M',
    'FEMALE': 'F',
    'UNKNOWN': 'X'
}

# %% [markdown]
# ## Read Victim data

# %%
df = pd.read_csv(storage.path_for('complaints/victims.csv'))

df = df.rename(columns={
    'CRID': 'crid',
    'Gender': 'gender',
    'Age': 'age',
    'Race': 'race'
})

# %% [markdown]
# ## Clean Victim data

# %%
cleaner = DataCleaner(
    schema={
        'race': [strip, titleize],
        'gender': [lambda x: gender_dict.get(x, '')],
        'age': [lambda x: round(x, 0) if x != None else None],
        'crid': [strip]
    }
)
cleaner.perform(df)
# Out:
# 100%|██████████| 4/4 [00:01<00:00,  2.90it/s]
#            crid gender   age      race
# 0       1000009      F  37.0  Hispanic
# 1       1000015      F  35.0     Black
# 2       1000015      F  24.0     Black
# 3       1000020      M  28.0     Black
# 4       1000021      M  26.0     Black
# 5       1000027      F   NaN     Black
# 6       1000034      M  27.0     Black
# 7       1000034      M  28.0     Black
# 8       1000043      M  29.0     Black
# 9       1000043      M  36.0     Black
# 10      1000054      F  25.0     Black
# 11      1000055      M  25.0     Black
# 12      1000055      M  26.0     Black
# 13      1000058      M  26.0  Hispanic
# 14      1000067      M   NaN     Black
# 15      1000083      M  38.0     Black
# 16      1000085      M  82.0  Hispanic
# 17      1000087      F  26.0     Black
# 18      1000093      M  26.0     Black
# 19      1000098      F  25.0     Black
# 20      1000101      M  27.0     Black
# 21      1000102      M  28.0  Hispanic
# 22      1000104      F  26.0     Black
# 23      1000105      M  27.0     Black
# 24      1000121      F  73.0     Black
# 25      1000128      F  52.0     Black
# 26      1000130      M  38.0     Black
# 27      1000131      F  25.0     Black
# 28      1000134      M  64.0     Black
# 29      1000152      M   NaN     Black
# ...         ...    ...   ...       ...
# 20193   1082102      M  22.0     Black
# 20194   1082136      M  60.0     Black
# 20195   1082182      M  35.0     Black
# 20196   1082188      M   NaN   Unknown
# 20197   1082226      M  68.0     Black
# 20198   1082271      M  71.0     Black
# 20199   1082300      M  46.0     Black
# 20200   1082323      F  33.0     Black
# 20201   1082346      M   NaN     Black
# 20202   1082354      M  20.0     White
# 20203   1082360      M  44.0     Black
# 20204   1082361      M  22.0     Black
# 20205   1082409      M   NaN     White
# 20206   1082434      F  29.0  Hispanic
# 20207   1082444      M  39.0   Unknown
# 20208   1082467      M  34.0     Black
# 20209   1082491      F  60.0     Black
# 20210   1082499      M   NaN   Unknown
# 20211   1082501      M   NaN   Unknown
# 20212   1082516      M  50.0     Black
# 20213   1082535      F  53.0     White
# 20214   1082599      M  44.0     Black
# 20215   1082607      M  29.0     Black
# 20216   1082610      M  32.0     Black
# 20217   1082657      M  29.0     Black
# 20218   1082661      M  58.0     Black
# 20219   1082664      M  37.0     Black
# 20220   1082695      M  48.0     White
# 20221   1082745      M  38.0     Black
# 20222  10077725      F  40.0     White
#
# [20223 rows x 4 columns]

# %% [markdown]
# #### Get the allegation's ids which complainants are associated with

# %%
crid_to_id_map = {}
for id, crid in Allegation.objects.using(import_db).all().values_list('id', 'crid'):
    crid_to_id_map[crid] = id

# %%
tqdm.pandas(tqdm_notebook(), desc='Get allegation id')
df['allegation_id'] = df['crid'].progress_apply(lambda x: crid_to_id_map.get(x, None))
del df['crid']
# Out:
# A Jupyter Widget
# Get allegation id: 100%|██████████| 20223/20223 [00:00<00:00, 812815.96it/s]

# %% [markdown]
# #### Drop all victims with invalid age

# %%
df = df[df['age'] > 0]

# %% [markdown]
# ## Import Victim data

# %% [markdown]
# #### Delete existing victims before importing

# %%
Victim.objects.using(import_db).delete()
# Out:
# (0, {u'data.Victim': 0})

# %% [markdown]
# #### Import Victim data and print out the imported data

# %%
tqdm.pandas(tqdm_notebook(), desc='Importing Victim data')
df.progress_apply(lambda x: Victim.objects.using(import_db).create(**x), axis=1)

pd.DataFrame.from_records(Victim.objects.using(import_db).all().values())
# Out:
#        age  allegation_id gender     id      race
# 0       37          56657      F      1  Hispanic
# 1       35          56660      F      2     Black
# 2       24          56660      F      3     Black
# 3       28          56664      M      4     Black
# 4       26          56665      M      5     Black
# 5       27          56676      M      6     Black
# 6       28          56676      M      7     Black
# 7       29          56683      M      8     Black
# 8       36          56683      M      9     Black
# 9       25          56692      F     10     Black
# 10      25          56693      M     11     Black
# 11      26          56693      M     12     Black
# 12      26          56695      M     13  Hispanic
# 13      38          56711      M     14     Black
# 14      82          56713      M     15  Hispanic
# 15      26          56715      F     16     Black
# 16      26          56718      M     17     Black
# 17      25          56722      F     18     Black
# 18      27          56725      M     19     Black
# 19      28          56726      M     20  Hispanic
# 20      26          56728      F     21     Black
# 21      27          56729      M     22     Black
# 22      73          56742      F     23     Black
# 23      52          56747      F     24     Black
# 24      38          56748      M     25     Black
# 25      25          56749      F     26     Black
# 26      64          56751      M     27     Black
# 27      25          56782      F     28  Hispanic
# 28      27          56782      F     29  Hispanic
# 29      40          56787      M     30     Black
# ...    ...            ...    ...    ...       ...
# 16160   29         109295      F  16161     Black
# 16161   37         109296      M  16162     Black
# 16162   19         109298      M  16163     Black
# 16163   29         109301      M  16164     Black
# 16164   38         109302      M  16165     Black
# 16165   22         109304      M  16166     Black
# 16166   60         109305      M  16167     Black
# 16167   35         109307      M  16168     Black
# 16168   68         109309      M  16169     Black
# 16169   71         109310      M  16170     Black
# 16170   46         109311      M  16171     Black
# 16171   33         109313      F  16172     Black
# 16172   20         109315      M  16173     White
# 16173   44         109316      M  16174     Black
# 16174   22         109317      M  16175     Black
# 16175   29         109320      F  16176  Hispanic
# 16176   39         109321      M  16177   Unknown
# 16177   34         109322      M  16178     Black
# 16178   60         109323      F  16179     Black
# 16179   50         109326      M  16180     Black
# 16180   53         109327      F  16181     White
# 16181   44         109328      M  16182     Black
# 16182   29         109330      M  16183     Black
# 16183   32         109331      M  16184     Black
# 16184   29         109332      M  16185     Black
# 16185   58         109333      M  16186     Black
# 16186   37         109334      M  16187     Black
# 16187   48         109335      M  16188     White
# 16188   38          51574      M  16189     Black
# 16189   40          73368      F  16190     White
#
# [16190 rows x 5 columns]

# %% [markdown]
# *Currently, we're exclusing the victims who have invalid age (negative numbers). We will check and import them when they're cleaned enough later.*
