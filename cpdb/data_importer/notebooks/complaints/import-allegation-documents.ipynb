# %%
import pandas as pd
import numpy as np
from tqdm import tqdm, tqdm_notebook, tqdm_pandas

from data.models import AttachmentFile, Allegation
from data_importer.base.cleaner import DataCleaner, strip
from data_importer.base.storage import AzureStorage

# %%
storage = AzureStorage(account_name='cpdbv2data', 
                       account_key='your-key-here',
                       share='data-v1')
import_db = 'import'

# %% [markdown]
# ## Read allegation documents data

# %%
df = pd.read_csv(
    storage.path_for('/allegation_attachment_v1_2.csv'),
    usecols=['file_type', 'title', 'url', 'additional_info', 'tag', 'original_url', 'crid']
)

# %% [markdown]
# ## Clean allegation data

# %%
cleaner = DataCleaner(
    schema={
        'crid': [strip]
    }
)
cleaner.perform(df)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 30.14it/s]
#      file_type                               title  \
# 0     document                      CPB CR 1014796
# 1     document                      CRID 283121 CR
# 2     document                      CRID 309153 CR
# 3     document                      CRID 289138 CR
# 4     document                      CRID 289965 CR
# 5     document                      CRID 289177 CR
# 6     document                      CPB CR 1016176
# 7     document                      CRID 289862 CR
# 8     document                      CPB CR 1009860
# 9     document                      CPB CR 1002203
# 10    document                      CRID 299707 CR
# 11    document                      CRID 294077 CR
# 12    document                      CRID 294619 CR
# 13    document                      CRID 295143 CR
# 14    document                     CRID 1007464 CR
# 15    document                      CRID 291990 CR
# 16    document                      CRID 314447 CR
# 17    document                     CRID 1002643 CR
# 18    document                      CPB CR 1017101
# 19    document                      CRID 293237 CR
# 20    document                      CRID 303350 CR
# 21    document                     CRID 1006219 CR
# 22    document                     CRID 1018786 CR
# 23    document                     CRID 1020192 CR
# 24    document                      CRID 282188 CR
# 25    document                      CRID 287495 CR
# 26    document                      CRID 280609 CR
# 27    document                      CPB CR 1005631
# 28    document                      CRID 293632 CR
# 29    document                      CPB CR 1010375
# ...        ...                                 ...
# 2115     audio                          Audio Clip
# 2116     audio  Log#1080972 - OEMC Transmission #6
# 2117     audio  Log#1080972 - OEMC Transmission #7
# 2118  document            CRID 1080972 AR (O'Neal)
# 2119  document                   CRID 1080972 OCIR
# 2120     video      Log#1080972 - In-Car Camera #3
# 2121  document        CRID 1080972 OBR (Pratscher)
# 2122  document            CRID 1080972 OBR (Rosen)
# 2123  document        CRID 1080972 TRR (Pratscher)
# 2124  document            CRID 1080972 TRR (Rosen)
# 2125     video     Log# 1081642 - Bodycam Video #2
# 2126  document           CRID 1081642 OBR - 1 of 4
# 2127  document           CRID 1081642 OBR - 2 of 4
# 2128  document           CRID 1081642 OBR - 3 of 4
# 2129  document           CRID 1081642 OBR - 4 of 4
# 2130  document           CRID 1081642 TRR - 4 of 4
# 2131  document           CRID 1081642 TRR - 3 of 4
# 2132  document           CRID 1081642 TRR - 2 of 4
# 2133  document           CRID 1081642 TRR - 1 of 4
# 2134     video     Log# 1081642 - Bodycam Video #1
# 2135  document          CRID 1081642 OCIR - 3 of 3
# 2136     video     Log# 1081642 - Bodycam Video #3
# 2137     video     Log# 1081642 - Bodycam Video #4
# 2138     video      Log#1081642 - In car camera #1
# 2139     video      Log#1081642 - In car camera #2
# 2140     video      Log#1081642 - In car camera #3
# 2143  https://www.documentcloud.org/documents/310876...
# 2144  https://www.documentcloud.org/documents/310876...
#
#                                         additional_info    tag  \
# 0     {"normalized_title": "13SR2315", "documentclou...    CPB
# 1     {"normalized_title": "cr-283121", "documentclo...     CR
# 2     {"normalized_title": "CRID-309153-CR", "docume...     CR
# 3     {"normalized_title": "CRID-289138-CR", "docume...     CR
# 4     {"normalized_title": "CRID-289965-CR", "docume...     CR
# 5     {"normalized_title": "CRID-289177-CR", "docume...     CR
# 6     {"normalized_title": "14SR232423252328", "docu...    CPB
# 7     {"normalized_title": "CRID-289862-CR", "docume...     CR
# 8     {"normalized_title": "14SR2327", "documentclou...    CPB
# 9     {"normalized_title": "13PB28352836", "document...    CPB
# 10    {"normalized_title": "CR-299707", "documentclo...     CR
# 11    {"normalized_title": "CRID-294077-CR", "docume...     CR
# 12    {"normalized_title": "CRID-294619-CR", "docume...     CR
# 13    {"normalized_title": "CRID-295143-CR", "docume...     CR
# 14    {"normalized_title": "cr-1007464", "documentcl...     CR
# 15    {"normalized_title": "cr-291990", "documentclo...     CR
# 16    {"normalized_title": "cr-314447", "documentclo...     CR
# 17    {"normalized_title": "cr-1002643", "documentcl...     CR
# 18    {"normalized_title": "14PB2858", "documentclou...    CPB
# 19    {"normalized_title": "CRID-293237-CR", "docume...     CR
# 20    {"normalized_title": "CRID-303350-CR", "docume...     CR
# 21    {"normalized_title": "CRID-1006219-CR", "docum...     CR
# 22    {"normalized_title": "CRID-1018786-CR", "docum...     CR
# 23    {"normalized_title": "CRID-1020192-CR", "docum...     CR
# 24    {"normalized_title": "cr-282188", "documentclo...     CR
# 25    {"normalized_title": "cr-287495", "documentclo...     CR
# 26    {"normalized_title": "CRID-280609-CR", "docume...     CR
# 27    {"normalized_title": "11PB2742Order", "documen...    CPB
# 28    {"normalized_title": "CRID-293632-CR", "docume...     CR
# 29    {"normalized_title": "14SR2323", "documentclou...    CPB
# ...                                                 ...    ...
# 2115                                                 {}  Audio
# 2116                                                 {}  Audio
# 2117                                                 {}  Audio
# 2118  {"documentcloud_id": "3108761", "normalized_ti...     AR
# 2119  {"documentcloud_id": "3108762", "normalized_ti...   OCIR
# 2120                                                 {}  Video
# 2121  {"documentcloud_id": "3108763", "normalized_ti...    OBR
# 2122  {"documentcloud_id": "3108764", "normalized_ti...    OBR
# 2123  {"documentcloud_id": "3108765", "normalized_ti...    TRR
# 2124  {"documentcloud_id": "3108766", "normalized_ti...    TRR
# 2125                                                 {}  Video
# 2126  {"documentcloud_id": "3108770", "normalized_ti...    OBR
# 2127  {"documentcloud_id": "3108771", "normalized_ti...    OBR
# 2128  {"documentcloud_id": "3108772", "normalized_ti...    OBR
# 2129  {"documentcloud_id": "3108773", "normalized_ti...    OBR
# 2130  {"documentcloud_id": "3108777", "normalized_ti...    TRR
# 2131  {"documentcloud_id": "3108776", "normalized_ti...    TRR
# 2132  {"documentcloud_id": "3108775", "normalized_ti...    TRR
# 2133  {"documentcloud_id": "3108774", "normalized_ti...    TRR
# 2134                                                 {}  Video
http://3enc4h3ly9ug43k0po27qqhq.wpengine.netdn...  1081642
#
# [2145 rows x 7 columns]

# %% [markdown]
# #### Get the allegation's ids which documents are associated with

# %%
df_allegations = pd.DataFrame.from_records(Allegation.objects.using(import_db).all().values('id', 'crid'))

# %%
def get_allegation_id(crid):
    df_found = df_allegations[df_allegations['crid']==crid]
    return df_found.iloc[0]['id'] if not df_found.empty else np.NaN

# %%
tqdm.pandas(tqdm_notebook(), desc='Get allegation id')
df['allegation_id'] = df['crid'].progress_apply(get_allegation_id)
del df['crid']
# Out:
# A Jupyter Widget
# Get allegation id: 100%|██████████| 2145/2145 [00:35<00:00, 60.73it/s]

# %% [markdown]
# #### Drop all documents which do not associated with any allegation

# %%
df = df[df['allegation_id'].notnull()]

# %% [markdown]
# #### Replace all `NaN` with `''`

# %%
df = df.where(pd.notnull(df), '')

# %% [markdown]
# ## Import Allegation Document data

# %% [markdown]
# #### Delete all existing documents before importing

# %%
AttachmentFile.objects.using(import_db).delete()
# Out:
# (0, {u'data.AttachmentFile': 0})

# %% [markdown]
# #### Import allegation document and print out the imported data

# %%
tqdm.pandas(tqdm_notebook(), desc='Importing allegation document')
df.progress_apply(lambda x: AttachmentFile.objects.using(import_db).update_or_create(**x), axis=1)

pd.DataFrame.from_records(AttachmentFile.objects.using(import_db).all().values())
# Out:
# A Jupyter Widget
# Importing allegation document: 32it [00:00, 314.95it/s]
# Importing allegation document: 791it [00:02, 353.55it/s]
#                                        additional_info  allegation_id  \
# 0    {"normalized_title": "13SR2315", "documentclou...          67017
# 1    {"normalized_title": "cr-283121", "documentclo...          23775
# 2    {"normalized_title": "CRID-309153-CR", "docume...          49851
# 3    {"normalized_title": "CRID-289138-CR", "docume...          30033
# 4    {"normalized_title": "CRID-289965-CR", "docume...          30846
# 5    {"normalized_title": "CRID-289177-CR", "docume...          30071
# 6    {"normalized_title": "14SR232423252328", "docu...          68062
# 7    {"normalized_title": "CRID-289862-CR", "docume...          30747
# 8    {"normalized_title": "14SR2327", "documentclou...          63931
# 9    {"normalized_title": "13PB28352836", "document...          58317
# 10   {"normalized_title": "CR-299707", "documentclo...          40456
# 11   {"normalized_title": "CRID-294077-CR", "docume...          34890
# 12   {"normalized_title": "CRID-294619-CR", "docume...          35426
# 13   {"normalized_title": "CRID-295143-CR", "docume...          35945
# 14   {"normalized_title": "cr-1007464", "documentcl...          62112
# 15   {"normalized_title": "cr-291990", "documentclo...          32831
# 16   {"normalized_title": "cr-314447", "documentclo...          55380
# 17   {"normalized_title": "cr-1002643", "documentcl...          58638
# 18   {"normalized_title": "14PB2858", "documentclou...          51502
# 19   {"normalized_title": "CRID-293237-CR", "docume...          34064
# 20   {"normalized_title": "CRID-303350-CR", "docume...          44081
# 21   {"normalized_title": "CRID-1006219-CR", "docum...          61229
# 22   {"normalized_title": "CRID-1018786-CR", "docum...          69950
# 23   {"normalized_title": "CRID-1020192-CR", "docum...          70943
# 24   {"normalized_title": "cr-282188", "documentclo...          22842
# 25   {"normalized_title": "cr-287495", "documentclo...          28476
# 26   {"normalized_title": "CRID-280609-CR", "docume...          21266
# 27   {"normalized_title": "11PB2742Order", "documen...          60848
# 28   {"normalized_title": "CRID-293632-CR", "docume...          34451
# 29   {"normalized_title": "14SR2323", "documentclou...          64341
# ..                                                 ...            ...
# 761                                                 {}         108661
# 762                                                 {}         108661
# 763                                                 {}         109184
# 764                                                 {}         109184
# 765                                                 {}         109184
# 766                                                 {}         109184
# 767                                                 {}         109184
# 768                                                 {}         109184
# 769                                                 {}         109184
# 770                                                 {}         109184
# 771                                                 {}         109184
# 772                                                 {}         109184
# 773                                                 {}         109184
# 774                                                 {}         109184
# 775                                                 {}         109184
# 776                                                 {}         109184
# 777                                                 {}         109184
# 778                                                 {}         109184
# 779                                                 {}         109184
# 780                                                 {}         109184
# 781                                                 {}         109184
# 782                                                 {}         109184
# 783                                                 {}         109184
# 784  {"documentcloud_id": "3108761", "normalized_ti...         109184
# 785  {"documentcloud_id": "3108762", "normalized_ti...         109184
# 786                                                 {}         109184
# 787  {"documentcloud_id": "3108763", "normalized_ti...         109184
# 788  {"documentcloud_id": "3108764", "normalized_ti...         109184
# 789  {"documentcloud_id": "3108765", "normalized_ti...         109184
# 790  {"documentcloud_id": "3108766", "normalized_ti...         109184
#
#     file_type   id                                       original_url    tag  \
# 0    document    1  http://documentcloud.org/documents/2646172-13S...    CPB
# 1    document    2  http://documentcloud.org/documents/2082448-cr-...     CR
# 2    document    3                                                        CR
# 3    document    4                                                        CR
# 4    document    5                                                        CR
# 5    document    6                                                        CR
# 6    document    7  http://documentcloud.org/documents/2646222-14S...    CPB
# 7    document    8                                                        CR
# 8    document    9  http://documentcloud.org/documents/2646214-14S...    CPB
# 9    document   10  http://documentcloud.org/documents/2646167-13P...    CPB
# 10   document   11  http://documentcloud.org/documents/2752280-CR-...     CR
# 11   document   12                                                        CR
# 12   document   13                                                        CR
# 13   document   14                                                        CR
# 14   document   15  http://documentcloud.org/documents/2631159-cr-...     CR
# 15   document   16  http://documentcloud.org/documents/1273484-cr-...     CR
# 16   document   17  http://documentcloud.org/documents/1273508-cr-...     CR
# 17   document   18  http://documentcloud.org/documents/1273509-cr-...     CR
# 18   document   19  http://documentcloud.org/documents/2646187-14P...    CPB
# 19   document   20                                                        CR
# 20   document   21                                                        CR
# 21   document   22                                                        CR
# 22   document   23                                                        CR
# 23   document   24                                                        CR
# 24   document   25  http://documentcloud.org/documents/1273477-cr-...     CR
# 25   document   26  http://documentcloud.org/documents/1273480-cr-...     CR
# 26   document   27                                                        CR
# 27   document   28  http://documentcloud.org/documents/2646152-11P...    CPB
# 28   document   29                                                        CR
# 29   document   30  http://documentcloud.org/documents/2646212-14S...    CPB
# ..        ...  ...                                                ...    ...
# 761     video  761           https://player.vimeo.com/video/170099750  Video
# 762     video  762           https://player.vimeo.com/video/170099620  Video
# 763     video  763           https://player.vimeo.com/video/178403273  Video
# 764     video  764           https://player.vimeo.com/video/178403333  Video
# 765     video  765           https://player.vimeo.com/video/178403334  Video
# 766     video  766           https://player.vimeo.com/video/178405120  Video
# 767     video  767           https://player.vimeo.com/video/178405121  Video
# 768     video  768           https://player.vimeo.com/video/178406348  Video
# 769     audio  769  https://w.soundcloud.com/player/?url=https%3A/...  Audio
# 770     video  771           https://player.vimeo.com/video/178399355  Video
# 771     video  772           https://player.vimeo.com/video/178371915  Video
# 772     video  773           https://player.vimeo.com/video/178371835  Video
# 773     video  774           https://player.vimeo.com/video/178371533  Video
# 774     video  775           https://player.vimeo.com/video/178406445  Video
# 775     video  776           https://player.vimeo.com/video/178406444  Video
# 776     video  777           https://player.vimeo.com/video/178406967  Video
# 777     video  778           https://player.vimeo.com/video/170880093  Video
# 778     audio  779  https://w.soundcloud.com/player/?url=https%3A/...  Audio
# 779     audio  780  https://w.soundcloud.com/player/?url=https%3A/...  Audio
# 780     audio  781  https://w.soundcloud.com/player/?url=https%3A/...  Audio
# 781     audio  782  https://w.soundcloud.com/player/?url=https%3A/...  Audio
# 782     audio  783  https://w.soundcloud.com/player/?url=https%3A/...  Audio
# 783     audio  784  https://w.soundcloud.com/player/?url=https%3A/...  Audio
# 784  document  785  http://3enc4h3ly9ug43k0po27qqhq.wpengine.netdn...     AR
# 785  document  786  http://3enc4h3ly9ug43k0po27qqhq.wpengine.netdn...   OCIR
# 786     video  787           https://player.vimeo.com/video/178399399  Video
# 787  document  788  http://3enc4h3ly9ug43k0po27qqhq.wpengine.netdn...    OBR
# 788  document  789  http://3enc4h3ly9ug43k0po27qqhq.wpengine.netdn...    OBR
# 789  document  790  http://3enc4h3ly9ug43k0po27qqhq.wpengine.netdn...    TRR
# 790  document  791  http://3enc4h3ly9ug43k0po27qqhq.wpengine.netdn...    TRR
#
#                                    title  \
# 0                         CPB CR 1014796
# 1                         CRID 283121 CR
# 2                         CRID 309153 CR
# 3                         CRID 289138 CR
# 4                         CRID 289965 CR
# 5                         CRID 289177 CR
# 6                         CPB CR 1016176
# 7                         CRID 289862 CR
# 8                         CPB CR 1009860
# 9                         CPB CR 1002203
# 10                        CRID 299707 CR
# 11                        CRID 294077 CR
# 12                        CRID 294619 CR
# 13                        CRID 295143 CR
# 14                       CRID 1007464 CR
# 15                        CRID 291990 CR
# 16                        CRID 314447 CR
# 17                       CRID 1002643 CR
# 18                        CPB CR 1017101
# 19                        CRID 293237 CR
# 20                        CRID 303350 CR
# 21                       CRID 1006219 CR
# 22                       CRID 1018786 CR
# 23                       CRID 1020192 CR
# 24                        CRID 282188 CR
# 25                        CRID 287495 CR
# 26                        CRID 280609 CR
# 27                        CPB CR 1005631
# 28                        CRID 293632 CR
# 29                        CPB CR 1010375
# ..                                   ...
# 761               Log#1080018 - Video #3
# 762               Log#1080018 - Video #1
# 763       Log#1080972 - In-Car Camera #6
# 764       Log#1080972 - In-Car Camera #8
# 765       Log#1080972 - In-Car Camera #7
# 766      Log#1080972 - In-Car Camera #10
# 767       Log#1080972 - In-Car Camera #9
# 768      Log#1080972 - In-Car Camera #11
# 769                           Audio Clip
# 770       Log#1080972 - In-Car Camera #5
# 771       Log#1080972 - In-Car Camera #2
# 772       Log#1080972 - In-Car Camera #1
# 773        Log#1080972 - Pod cam footage
# 774  Log# 1080972 - 3rd party footage #2
# 775  Log# 1080972 - 3rd party footage #3
# 776  Log# 1080972 - 3rd party footage #4
# 777     Log# 1080972 - 3rd party footage
# 778   Log#1080972 - OEMC Transmission #2
# 779                           Audio Clip
# 780   Log#1080972 - OEMC Transmission #4
# 781                           Audio Clip
# 782   Log#1080972 - OEMC Transmission #6
# 783   Log#1080972 - OEMC Transmission #7
# 784             CRID 1080972 AR (O'Neal)
# 785                    CRID 1080972 OCIR
# 786       Log#1080972 - In-Car Camera #3
# 787         CRID 1080972 OBR (Pratscher)
