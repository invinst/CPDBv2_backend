# %%
import pandas as pd
import numpy as np
from tqdm import tqdm, tqdm_notebook, tqdm_pandas

from data.models import Complainant, Allegation
from data_importer.base.cleaner import DataCleaner, strip, titleize
from data_importer.base.storage import AzureStorage

# %%
storage = AzureStorage(account_name='cpdbv2data', 
                       account_key='your-key-here',
                       share='cleaned-data')
import_db = 'import'

# %%
gender_dict = {
    'MALE': 'M',
    'FEMALE': 'F',
    'UNKNOWN': 'X'
}

# %% [markdown]
# ## Read Complainants data

# %%
df = pd.read_csv(storage.path_for('complaints/complainants.csv'))

df = df.rename(columns={
    'CRID': 'crid',
    'Gender': 'gender',
    'Age': 'age',
    'Race': 'race'
})

# %% [markdown]
# ## Clean Complaints data

# %%
cleaner = DataCleaner(
    schema={
        'race': [strip, titleize],
        'gender': [lambda x: gender_dict.get(x, '')],
        'age': [lambda x: round(x, 0) if x != None else None],
        'crid': [strip]
    }
)
cleaner.perform(df)
# Out:
# 100%|██████████| 4/4 [00:02<00:00,  1.30it/s]
#            crid gender    age      race
# 0       1000000      F   49.0     White
# 1       1000001      M   32.0     Black
# 2       1000002      M   43.0  Hispanic
# 3       1000004      M   60.0  Hispanic
# 4       1000004      M   53.0     White
# 5       1000005      F   35.0     Black
# 6       1000006      M   53.0     Black
# 7       1000007      F   56.0     White
# 8       1000009      M   39.0  Hispanic
# 9       1000010      M   43.0     Black
# 10      1000014      F   55.0     Black
# 11      1000015      F    NaN     Black
# 12      1000016      M   67.0     Black
# 13      1000017      F   34.0  Hispanic
# 14      1000018      M    NaN   Unknown
# 15      1000020      M   33.0     Black
# 16      1000021      F   55.0     Black
# 17      1000022      F   68.0     Black
# 18      1000023      M   52.0     Black
# 19      1000024      F   32.0  Hispanic
# 20      1000025      F   52.0  Hispanic
# 21      1000026      F    NaN     Black
# 22      1000026      F   28.0     Black
# 23      1000027      F    NaN  Hispanic
# 24      1000028      M   35.0  Hispanic
# 25      1000030      M   37.0     Black
# 26      1000031      F   44.0     Black
# 27      1000033      M   60.0     Black
# 28      1000034      F   57.0     Black
# 29      1000035      F   58.0     White
# ...         ...    ...    ...       ...
# 48184   1081975      M   35.0     Black
# 48185   1081979      M -901.0   Unknown
# 48186   1081980      M   46.0     Black
# 48187   1081981      M    NaN     White
# 48188   1081981      M   56.0     Black
# 48189   1081994      F   48.0     Black
# 48190   1082005      M    NaN   Unknown
# 48191   1082047      M    NaN   Unknown
# 48192   1082049      M    NaN     White
# 48193   1082050      F    NaN   Unknown
# 48194   1082068      M    NaN   Unknown
# 48195   1082094      M    NaN   Unknown
# 48196   1082097      M    NaN   Unknown
# 48197   1082100      M   41.0     Black
# 48198   1082102      M    NaN     White
# 48199   1082182      M    NaN   Unknown
# 48200   1082189      M   45.0     Black
# 48201   1082322      M   39.0     Black
# 48202   1082361      M    NaN   Unknown
# 48203   1082402      M   41.0  Hispanic
# 48204   1082467      F    NaN     White
# 48205   1082499      F    NaN   Unknown
# 48206   1082516      M    NaN   Unknown
# 48207   1082599      F    NaN   Unknown
# 48208   1082600      M    NaN   Unknown
# 48209   1082657      M    NaN   Unknown
# 48210   1082661      M    NaN   Unknown
# 48211  10773250      F   53.0     Black
# 48212  10819810      M   46.0     Black
# 48213  10851356      M   54.0     Black
#
# [48214 rows x 4 columns]

# %% [markdown]
# #### Get the allegation's ids which complainants are associated with

# %%
crid_to_id_map = {}
for id, crid in Allegation.objects.using(import_db).all().values_list('id', 'crid'):
    crid_to_id_map[crid] = id

# %%
tqdm.pandas(tqdm_notebook(), desc='Get allegation id')
df['allegation_id'] = df['crid'].progress_apply(lambda x: crid_to_id_map.get(x, None))
del df['crid']
# Out:
# A Jupyter Widget
# Get allegation id: 100%|██████████| 48214/48214 [00:00<00:00, 887134.89it/s]

# %% [markdown]
# #### Drop all complainants with invalid age

# %%
df = df[df['age'] > 0]

# %% [markdown]
# ## Import Complainants data

# %% [markdown]
# #### Delete existing complainants before importing

# %%
Complainant.objects.using(import_db).delete()
# Out:
# (0, {u'data.Complainant': 0})

# %% [markdown]
# #### Import complainants data and print out the imported data

# %%
tqdm.pandas(tqdm_notebook(), desc='Importing complainant data')
df.progress_apply(lambda x: Complainant.objects.using(import_db).create(**x), axis=1)

pd.DataFrame.from_records(Complainant.objects.using(import_db).all().values())
# Out:
# A Jupyter Widget
# Importing complainant data: 106it [00:00, 1052.21it/s]
# Importing complainant data: 40831it [00:41, 986.00it/s]
#        age  allegation_id gender     id      race
# 0       49          56650      F      1     White
# 1       32          56651      M      2     Black
# 2       43          56652      M      3  Hispanic
# 3       60          56653      M      4  Hispanic
# 4       53          56653      M      5     White
# 5       35          56654      F      6     Black
# 6       53          56655      M      7     Black
# 7       56          56656      F      8     White
# 8       39          56657      M      9  Hispanic
# 9       43          56658      M     10     Black
# 10      55          56659      F     11     Black
# 11      67          56661      M     12     Black
# 12      34          56662      F     13  Hispanic
# 13      33          56664      M     14     Black
# 14      55          56665      F     15     Black
# 15      68          56666      F     16     Black
# 16      52          56667      M     17     Black
# 17      32          56668      F     18  Hispanic
# 18      52          56669      F     19  Hispanic
# 19      28          56670      F     20     Black
# 20      35          56672      M     21  Hispanic
# 21      37          56673      M     22     Black
# 22      44          56674      F     23     Black
# 23      60          56675      M     24     Black
# 24      57          56676      F     25     Black
# 25      58          56677      F     26     White
# 26      38          56678      M     27     Black
# 27      57          56679      F     28     Black
# 28      61          56680      F     29     Black
# 29      36          56681      M     30     Black
# ...    ...            ...    ...    ...       ...
# 40801   29         109226      F  40802     Black
# 40802   40         109231      F  40803     White
# 40803   22         109232      M  40804     Black
# 40804   47         109235      M  40805  Hispanic
# 40805   68         109237      F  40806     Black
# 40806   54         109239      F  40807     Black
# 40807   40         109243      M  40808     White
# 40808   47         109244      M  40809     White
# 40809   26         109245      M  40810     White
# 40810   43         109247      M  40811     Black
# 40811   44         109251      F  40812     Black
# 40812   44         109255      M  40813     White
# 40813   47         109258      M  40814  Hispanic
# 40814   29         109262      M  40815     Black
# 40815   56         109264      F  40816     White
# 40816   28         109269      M  40817     Black
# 40817   52         109278      M  40818  Hispanic
# 40818   48         109281      M  40819     Black
# 40819   29         109288      M  40820     Black
# 40820   35         109290      M  40821     Black
# 40821   46         109292      M  40822     Black
# 40822   56         109293      M  40823     Black
# 40823   48         109294      F  40824     Black
# 40824   41         109303      M  40825     Black
# 40825   45         109308      M  40826     Black
# 40826   39         109312      M  40827     Black
# 40827   41         109318      M  40828  Hispanic
# 40828   53         109337      F  40829     Black
# 40829   46         109338      M  40830     Black
# 40830   54         109339      M  40831     Black
#
# [40831 rows x 5 columns]

# %% [markdown]
# *Currently, we're exclusing the complaints who have invalid age (negative numbers). We will check and import them when they're cleaned enough later.*
