# %%
import pandas as pd
import numpy as np
from tqdm import tqdm, tqdm_notebook, tqdm_pandas

from data.models import Allegation
from data_importer.base.cleaner import DataCleaner, strip
from data_importer.base.storage import AzureStorage
from document_cloud.document_clould_uploader import DocumentCloudUploader, DOCUMENT_TITLE_KEYWORD_TYPE_MAPPING
from data.constants import MEDIA_TYPE_DOCUMENT

# %%
storage = AzureStorage(account_name='cpdbv2data', 
                       account_key='your-key-here',
                       share='crawled-data')
import_db = 'import'

# %% [markdown]
# ## Read the data

# %%
df = pd.read_csv(
    storage.path_for('/ipra_crawled_complaint_attachments_data.csv'),
    usecols=['crid', 'type', 'link', 'title']
)

df = df.rename(columns={
    'type': 'file_type',
    'link': 'original_url'
})

# %% [markdown]
# ## Clean the data

# %%
df = DataCleaner(schema={
    'crid': [strip]
}).perform(df)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 22.65it/s]

# %% [markdown]
# #### Exludes attachments which its associated crids are not in the imported complaints data

# %%
crids = set(Allegation.objects.using(import_db).all().values_list('crid', flat=True))

# %%
df = df[df['crid'].apply(lambda x: x in crids)]

# %% [markdown]
# #### Add url field, tag field and addition_info field

# %%
def get_attachment_tag(row):
    file_type = row['file_type']
    title = row['title']
    if file_type == MEDIA_TYPE_DOCUMENT:
        for key in DOCUMENT_TITLE_KEYWORD_TYPE_MAPPING:
            if title.startswith(key):
                return DOCUMENT_TITLE_KEYWORD_TYPE_MAPPING[key]
        return 'Other'
    else:
        return file_type.capitalize()

# %%
tqdm.pandas(tqdm_notebook(), desc='Adding url field, tag field and addition_info field')
df = df.assign(
    url=df.progress_apply(lambda x: x['original_url'], axis=1),
    tag=df.progress_apply(get_attachment_tag, axis=1),
    additional_info=df.progress_apply(lambda x: {}, axis=1)
)
# Out:
# A Jupyter Widget
# Adding url field, tag field and addition_info field: 100%|██████████| 576/576 [00:00<00:00, 50335.84it/s]
# Adding url field, tag field and addition_info field: 100%|██████████| 576/576 [00:00<00:00, 36501.97it/s]
# Adding url field, tag field and addition_info field: 100%|██████████| 576/576 [00:00<00:00, 141240.52it/s]

# %% [markdown]
# #### Get the allegation's ids which documents are associated with

# %%
df_allegations = pd.DataFrame.from_records(Allegation.objects.using(import_db).all().values('id', 'crid'))

# %%
def get_allegation_id(crid):
    df_found = df_allegations[df_allegations['crid']==crid]
    return df_found.iloc[0]['id'] if not df_found.empty else np.NaN

# %%
tqdm.pandas(tqdm_notebook(), desc='Get allegation id')
df['allegation_id'] = df['crid'].progress_apply(get_allegation_id)
del df['crid']
# Out:
# A Jupyter Widget
# Get allegation id:   1%|          | 7/576 [00:00<00:08, 69.99it/s]
# Get allegation id: 100%|██████████| 576/576 [00:09<00:00, 58.99it/s]

# %% [markdown]
# ## Import complaint attachments data

# %% [markdown]
# #### Delete all existing attachments before importing

# %%
AttachmentFile.objects.using(import_db).delete()
# Out:
# (0, {u'data.AttachmentFile': 0})

# %% [markdown]
# #### Import and print out the imported data

# %%
tqdm.pandas(tqdm_notebook(), desc='Importing document')
df.progress_apply(lambda x: AttachmentFile.objects.using(import_db).create(**x), axis=1)

pd.DataFrame.from_records(AttachmentFile.objects.using(import_db).all().values())
# Out:
# A Jupyter Widget
# Importing document: 100%|██████████| 576/576 [00:00<00:00, 744.69it/s]
#     additional_info  allegation_id file_type   id  \
# 0                {}         109233  document    1
# 1                {}         109233  document    2
# 2                {}         109233  document    3
# 3                {}         109233  document    4
# 4                {}         109233  document    5
# 5                {}         109233  document    6
# 6                {}         109233  document    7
# 7                {}         109233  document    8
# 8                {}         109233  document    9
# 9                {}         109233  document   10
# 10               {}         109233  document   11
# 11               {}         109233  document   12
# 12               {}         109233  document   13
# 13               {}         109233  document   14
# 14               {}         109233  document   15
# 15               {}         109275     video   16
# 16               {}         109275  document   17
# 17               {}         109275  document   18
# 18               {}         109275  document   19
# 19               {}         109275  document   20
# 20               {}         109318  document   21
# 21               {}         109318  document   22
# 22               {}         109318  document   23
# 23               {}         109318  document   24
# 24               {}         109318  document   25
# 25               {}         109318  document   26
# 26               {}         109318  document   27
# 27               {}         109204     audio   28
# 28               {}         109204     video   29
# 29               {}         109204     video   30
# ..              ...            ...       ...  ...
# 546              {}          92264  document  547
# 547              {}          92264  document  548
# 548              {}          92264  document  549
# 549              {}          92264  document  550
# 550              {}          92264  document  551
# 551              {}          92264  document  552
# 552              {}          92264  document  553
# 553              {}          92264  document  554
# 554              {}          92264  document  555
# 555              {}          92264  document  556
# 556              {}          92264  document  557
# 557              {}          92264  document  558
# 558              {}          92264  document  559
# 559              {}          92264  document  560
# 560              {}          92264  document  561
# 561              {}          92264  document  562
# 562              {}          92264  document  563
# 563              {}          92264  document  564
# 564              {}          92264  document  565
# 565              {}          92264  document  566
# 566              {}          92264  document  567
# 567              {}          92264  document  568
# 568              {}          92264  document  569
# 569              {}          92264  document  570
# 570              {}          92264  document  571
# 571              {}          92264  document  572
# 572              {}          92264  document  573
# 573              {}          92264  document  574
# 574              {}          92264  document  575
# 575              {}         106874     video  576
#
#                                           original_url    tag  \
# 0    http://www.chicagocopa.org/wp-content/uploads/...     AR
# 1    http://www.chicagocopa.org/wp-content/uploads/...     AR
# 2    http://www.chicagocopa.org/wp-content/uploads/...     AR
# 3    http://www.chicagocopa.org/wp-content/uploads/...     AR
# 4    http://www.chicagocopa.org/wp-content/uploads/...   OCIR
# 5    http://www.chicagocopa.org/wp-content/uploads/...    OBR
# 6    http://www.chicagocopa.org/wp-content/uploads/...    OBR
# 7    http://www.chicagocopa.org/wp-content/uploads/...    OBR
# 8    http://www.chicagocopa.org/wp-content/uploads/...    OBR
# 9    http://www.chicagocopa.org/wp-content/uploads/...    OBR
# 10   http://www.chicagocopa.org/wp-content/uploads/...    TRR
# 11   http://www.chicagocopa.org/wp-content/uploads/...    TRR
# 12   http://www.chicagocopa.org/wp-content/uploads/...    TRR
# 13   http://www.chicagocopa.org/wp-content/uploads/...    TRR
# 14   http://www.chicagocopa.org/wp-content/uploads/...    TRR
# 15            https://player.vimeo.com/video/194529403  Video
# 16   http://www.chicagocopa.org/wp-content/uploads/...     AR
# 17   http://www.chicagocopa.org/wp-content/uploads/...  Other
# 18   http://www.chicagocopa.org/wp-content/uploads/...    TRR
# 19   http://www.chicagocopa.org/wp-content/uploads/...    TRR
# 20   http://www.chicagocopa.org/wp-content/uploads/...     AR
# 21   http://www.chicagocopa.org/wp-content/uploads/...   OCIR
# 22   http://www.chicagocopa.org/wp-content/uploads/...   OCIR
# 23   http://www.chicagocopa.org/wp-content/uploads/...   OCIR
# 24   http://www.chicagocopa.org/wp-content/uploads/...    OBR
# 25   http://www.chicagocopa.org/wp-content/uploads/...    TRR
# 26   http://www.chicagocopa.org/wp-content/uploads/...    TRR
# 27   https://w.soundcloud.com/player/?url=https%3A/...  Audio
# 28            https://player.vimeo.com/video/188355255  Video
# 29            https://player.vimeo.com/video/188354332  Video
# ..                                                 ...    ...
# 546  http://www.chicagocopa.org/wp-content/uploads/...     AR
# 547  http://www.chicagocopa.org/wp-content/uploads/...   OCIR
# 548  http://www.chicagocopa.org/wp-content/uploads/...   OCIR
# 549  http://www.chicagocopa.org/wp-content/uploads/...   OCIR
# 550  http://www.chicagocopa.org/wp-content/uploads/...   OCIR
# 551  http://www.chicagocopa.org/wp-content/uploads/...    OBR
#