# %%
from django.contrib.gis.geos import Point

import pandas as pd
from tqdm import tqdm, tqdm_notebook, tqdm_pandas

from data.models import Allegation, Area
from data_importer.base.storage import AzureStorage
from data_importer.base.cleaner import DataCleaner, to_int, strip

# %%
storage = AzureStorage(account_name='cpdbv2data', 
                       account_key='<add-your-key-here>',
                       share='cleaned-data')
import_db = 'import'

# %% [markdown]
# ## Load GEO data file

# %%
df = pd.read_csv(
    storage.path_for('complaints/allegation_areas.csv'),
    usecols=['CRID', 'lat', 'lng']
)

# %% [markdown]
# #### Reformat CRID to string

# %%
DataCleaner(
    schema={
        'CRID': [strip, to_int]
    }
).perform(df)
# Out:
# 100%|██████████| 1/1 [00:04<00:00,  4.26s/it]
#             CRID        lat        lng
# 0         258996  41.894921 -87.759053
# 1         258997  41.877184 -87.733444
# 2         258998  41.890882 -87.628025
# 3         258999  41.875600 -87.624400
# 4         259000  41.894921 -87.759053
# 5         259001  41.737596 -87.552228
# 6         259002  41.734883 -87.664603
# 7         259003  41.875600 -87.624400
# 8         259005  41.875600 -87.624400
# 9         259006  41.875600 -87.624400
# 10        259007  41.920616 -87.743785
# 11        259008  41.864825 -87.625625
# 12        259010  41.729169 -87.604965
# 13        259011  41.814901 -87.643261
# 14        259012  42.012567 -87.680291
# 15        259013  41.703720 -87.625952
# 16        259014  41.873993 -87.704261
# 17        259015  41.875600 -87.624400
# 18        259016  41.766614 -87.645924
# 19        259017  41.873718 -87.704735
# 20        259018  41.777352 -87.687329
# 21        259019  41.934983 -87.717629
# 22        259020  41.875600 -87.624400
# 23        259021  41.877443 -87.689215
# 24        259023  41.875600 -87.624400
# 25        259024  41.867223 -87.640718
# 26        259025        NaN        NaN
# 27        259026  41.959687 -87.702230
# 28        259028  41.875600 -87.624400
# 29        259030  41.993530 -87.654724
# ...          ...        ...        ...
# 109309   1082271  41.870720 -87.753531
# 109310   1082300  41.883115 -87.629997
# 109311   1082322  41.785902 -87.654876
# 109312   1082323  41.963880 -87.816795
# 109313   1082346  41.752340 -87.656203
# 109314   1082354  42.001242 -87.693903
# 109315   1082360  41.777545 -87.684247
# 109316   1082361  41.884880 -87.725758
# 109317   1082402  41.838659 -87.731841
# 109318   1082409  41.871592 -87.629800
# 109319   1082434  41.836463 -87.638131
# 109320   1082444  41.736518 -87.613502
# 109321   1082467  41.906714 -87.746104
# 109322   1082491  41.830636 -87.623783
# 109323   1082499  41.971630 -87.656315
# 109324   1082501  41.876717 -87.695733
# 109325   1082516  41.781463 -87.653153
# 109326   1082535  41.839741 -87.654590
# 109327   1082599  41.829368 -87.613186
# 109328   1082600  41.875600 -87.624400
# 109329   1082607  41.757835 -87.586122
# 109330   1082610  41.884596 -87.754213
# 109331   1082657  41.862955 -87.656894
# 109332   1082661  41.861062 -87.711753
# 109333   1082664  41.801784 -87.630703
# 109334   1082695  41.947304 -87.661879
# 109335  10639955  41.875600 -87.624400
# 109336  10773250  41.830636 -87.623783
# 109337  10819810  41.897770 -87.720729
# 109338  10851356  41.858093 -87.627502
#
# [109339 rows x 3 columns]

# %% [markdown]
# ## Import GEO data to database

# %%
def import_allegation_area(data):
    lat = data['lat']
    lng = data['lng']
    if lat and lng:
        point = Point(x=lng, y=lat)
        crid = str(int(float(data['CRID'])))
        allegation = Allegation.objects.using(import_db).get(crid=crid)
        allegation.areas.clear()
        areas = Area.objects.using(import_db).filter(polygon__intersects=point)
        for area in areas:
            allegation.areas.add(area)

# %%
tqdm.pandas(tqdm_notebook(), desc='Importing allegation areas')
df.progress_apply(import_allegation_area, axis=1)
# Out:
# A Jupyter Widget
# Importing allegation areas: 100%|██████████| 109339/109339 [58:52<00:00, 30.95it/s]
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
# 5         None
# 6         None
# 7         None
# 8         None
# 9         None
# 10        None
# 11        None
# 12        None
# 13        None
# 14        None
# 15        None
# 16        None
# 17        None
# 18        None
# 19        None
# 20        None
# 21        None
# 22        None
# 23        None
# 24        None
# 25        None
# 26        None
# 27        None
# 28        None
# 29        None
#           ...
# 109309    None
# 109310    None
# 109311    None
# 109312    None
# 109313    None
# 109314    None
# 109315    None
# 109316    None
# 109317    None
# 109318    None
# 109319    None
# 109320    None
# 109321    None
# 109322    None
# 109323    None
# 109324    None
# 109325    None
# 109326    None
# 109327    None
# 109328    None
# 109329    None
# 109330    None
# 109331    None
# 109332    None
# 109333    None
# 109334    None
# 109335    None
# 109336    None
# 109337    None
# 109338    None
# Length: 109339, dtype: object
